# %% [markdown]
# # Data Analysis Quiz (1 hr 15 min)
#
# This dataset contains information about cars from different years. Each row represents a car.
#
# Columns include:
# - mpg (fuel efficiency)
# - cylinders
# - horsepower
# - weight
# - origin (USA, Europe, Japan)
#
# Use the dataset to answer the following questions. Enter your final answers in Canvas.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
df = pd.read_csv(url)

df.head()

# %% [markdown]
# ## Question 1
# How many rows and columns are in the dataset?

# %% [markdown]
# ## Question 2
# What is the average MPG (round to 2 decimal places)?

# %% [markdown]
# ## Question 3
# What is the maximum horsepower?

# %% [markdown]
# ## Question 4
# How many cars have more than 6 cylinders?

# %% [markdown]
# ## Question 5
# What is the average MPG for cars with 4 cylinders?

# %% [markdown]
# ## Question 6
# Which origin has the highest average MPG?

# %% [markdown]
# ## Question 7
# How many cars have missing horsepower values?

# %% [markdown]
# ## Question 8
# What is the average weight of cars produced in Japan?

# %% [markdown]
# ## Question 9
# How many cars have MPG above the overall average?
